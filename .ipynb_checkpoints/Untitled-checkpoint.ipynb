# %%
num = 1
int_1 = 0
while num < 9:
    num += 1
    print("{}단 출력".format(num))
    
    while int_1 < 9:
        int_1 += 1
        result = num*int_1
        print("{}x{}={}".format(num,int_1,result))
# Out:
# 2단 출력
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# 2x1=2
# ...
